# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# 1.	Data Cleaning and Preparation

# %%
df=pd.read_csv(r"C:\Users\abhishekgh\Desktop\ExcelR\Cardiotocographic.csv")

# %%
df
# Out:
#               LB        AC        FM        UC        DL   DS   DP  ASTV  \
# 0     120.000000  0.000000  0.000000  0.000000  0.000000  0.0  0.0  73.0
# 1     132.000000  0.006380  0.000000  0.006380  0.003190  0.0  0.0  17.0
# 2     133.000000  0.003322  0.000000  0.008306  0.003322  0.0  0.0  16.0
# 3     134.000000  0.002561  0.000000  0.007742  0.002561  0.0  0.0  16.0
# 4     131.948232  0.006515  0.000000  0.008143  0.000000  0.0  0.0  16.0
# ...          ...       ...       ...       ...       ...  ...  ...   ...
# 2121  140.000000  0.000000  0.961268  0.007426  0.000000  0.0  0.0  79.0
# 2122  140.000000  0.000775  0.000000  0.006979  0.000000  0.0  0.0  78.0
# 2123  140.000000  0.000980  0.000000  0.006863  0.000000  0.0  0.0  79.0
# 2124  140.000000  0.000679  0.000000  0.006110  0.000000  0.0  0.0  78.0
# 2125  142.000000  0.001616 -0.000188  0.008078  0.000000  0.0  0.0  74.0
#
#       MSTV       ALTV  MLTV  Width  Tendency       NSP
# ...

# %% [markdown]
# Missing Values

# %%
df.head()
# Out:
#            LB        AC   FM        UC        DL   DS   DP  ASTV  MSTV  ALTV  \
# 0  120.000000  0.000000  0.0  0.000000  0.000000  0.0  0.0  73.0   0.5  43.0
# 1  132.000000  0.006380  0.0  0.006380  0.003190  0.0  0.0  17.0   2.1   0.0
# 2  133.000000  0.003322  0.0  0.008306  0.003322  0.0  0.0  16.0   2.1   0.0
# 3  134.000000  0.002561  0.0  0.007742  0.002561  0.0  0.0  16.0   2.4   0.0
# 4  131.948232  0.006515  0.0  0.008143  0.000000  0.0  0.0  16.0   2.4   0.0
#
#    MLTV  Width  Tendency  NSP
# 0   2.4   64.0  0.999926  2.0
# 1  10.4  130.0  0.000000  1.0
# 2  13.4  130.0  0.000000  1.0
# 3  23.0  117.0  1.000000  1.0
# 4  19.9  117.0  1.000000  1.0

# %%
df.tail()
# Out:
#          LB        AC        FM        UC   DL   DS   DP  ASTV  MSTV  \
# 2121  140.0  0.000000  0.961268  0.007426  0.0  0.0  0.0  79.0   0.2
# 2122  140.0  0.000775  0.000000  0.006979  0.0  0.0  0.0  78.0   0.4
# 2123  140.0  0.000980  0.000000  0.006863  0.0  0.0  0.0  79.0   0.4
# 2124  140.0  0.000679  0.000000  0.006110  0.0  0.0  0.0  78.0   0.4
# 2125  142.0  0.001616 -0.000188  0.008078  0.0  0.0  0.0  74.0   0.4
#
#            ALTV  MLTV  Width  Tendency       NSP
# 2121  25.000000   7.2   40.0       0.0  2.000000
# 2122  22.000000   7.1   66.0       1.0  2.000000
# 2123  20.000000   6.1   67.0       1.0  1.990464
# 2124  27.000000   7.0   66.0       1.0  2.000000
# 2125  35.857183   5.0   42.0       0.0  1.000000

# %%
df.shape
# Out:
# (2126, 14)

# %%
df.size
# Out:
# 29764

# %%
print(df.dtypes)
# Out:
# LB          float64
# AC          float64
# FM          float64
# UC          float64
# DL          float64
# DS          float64
# DP          float64
# ASTV        float64
# MSTV        float64
# ALTV        float64
# MLTV        float64
# Width       float64
# Tendency    float64
# NSP         float64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2126 entries, 0 to 2125
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   LB        2105 non-null   float64
#  1   AC        2106 non-null   float64
#  2   FM        2126 non-null   float64
#  3   UC        2126 non-null   float64
#  4   DL        2126 non-null   float64
#  5   DS        2105 non-null   float64
#  6   DP        2105 non-null   float64
#  7   ASTV      2126 non-null   float64
#  8   MSTV      2126 non-null   float64
#  9   ALTV      2126 non-null   float64
#  10  MLTV      2105 non-null   float64
#  11  Width     2105 non-null   float64
#  12  Tendency  2105 non-null   float64
#  13  NSP       2105 non-null   float64
# dtypes: float64(14)
# memory usage: 232.7 KB

# %%
df[df.duplicated()]
# Out:
#          LB        AC   FM        UC   DL   DS   DP  ASTV  MSTV  ALTV  MLTV  \
# 1115  122.0  0.000000  0.0  0.000000  0.0  0.0  0.0  19.0   1.9   0.0  15.1
# 1458  148.0  0.004717  0.0  0.002358  0.0  0.0  0.0  40.0   0.9   0.0  10.6
#
#       Width  Tendency  NSP
# 1115   39.0       0.0  1.0
# 1458   35.0       0.0  1.0

# %%
df.isnull().sum()
# Out:
# LB          21
# AC          20
# FM           0
# UC           0
# DL           0
# DS          21
# DP          21
# ASTV         0
# MSTV         0
# ALTV         0
# MLTV        21
# Width       21
# Tendency    21
# NSP         21
# dtype: int64

# %%
df.columns
# Out:
# Index(['LB', 'AC', 'FM', 'UC', 'DL', 'DS', 'DP', 'ASTV', 'MSTV', 'ALTV',
#        'MLTV', 'Width', 'Tendency', 'NSP'],
#       dtype='object')

# %%
num_col=[i for i in df.columns if df[i].dtypes!='O']

# %%
num_col
# Out:
# ['LB',
#  'AC',
#  'FM',
#  'UC',
#  'DL',
#  'DS',
#  'DP',
#  'ASTV',
#  'MSTV',
#  'ALTV',
#  'MLTV',
#  'Width',
#  'Tendency',
#  'NSP']

# %%
cat_col=[i for i in df.columns if df[i].dtypes=='O']

# %%
cat_col
# Out:
# []

# %%
df.isnull().sum()
# Out:
# LB          21
# AC          20
# FM           0
# UC           0
# DL           0
# DS          21
# DP          21
# ASTV         0
# MSTV         0
# ALTV         0
# MLTV        21
# Width       21
# Tendency    21
# NSP         21
# dtype: int64

# %% [markdown]
# 2.Statastical Summary

# %% [markdown]
# Mean=The mean (or average) is the sum of all values divided by the number of values. It provides a measure of the central location of the data.
# Median=The median is the middle value when the data is sorted in ascending order.It is a measure of central tendency that is less sensitive to outliers than the mean.
# Interquartile Range (IQR)=The IQR measures the range within which the middle 50% of the data falls. It is the difference between the 75th percentile (Q3) and the 25th percentile (Q1). It helps to understand the spread of the central portion of the data and is useful for identifying outliers.

# %%
LB_mean=df['LB'].mean()
LB_mean
# Out:
# 133.3435983550352

# %%
AC_mean=df['AC'].mean()
AC_mean
# Out:
# 0.0032189782438000465

# %%
DC_mean=df['DS'].mean()
DC_mean
# Out:
# 2.5089835057102827e-06

# %%
DP_mean=df['DP'].mean()
DP_mean
# Out:
# 0.00017515121174634704

# %%
MLTV_median=df['MLTV'].median()
MLTV_median
# Out:
# 7.4

# %%
Width_median=df['Width'].median()
Width_median
# Out:
# 67.0

# %%
Tendency_mean=df['Tendency'].mean()
Tendency_mean
# Out:
# 0.3163714038702473

# %%
NSP_mean=df['NSP'].mean()
NSP_mean
# Out:
# 1.304507175110962

# %%
df1=df.fillna({'LB':LB_mean,'AC':AC_mean,'DS':DC_mean,'DP':DP_mean,'MLTV':MLTV_median,'Width':Width_median,'Tendency':Tendency_mean,'NSP':NSP_mean})

# %%
df1
# Out:
#               LB        AC        FM        UC        DL   DS   DP  ASTV  \
# 0     120.000000  0.000000  0.000000  0.000000  0.000000  0.0  0.0  73.0
# 1     132.000000  0.006380  0.000000  0.006380  0.003190  0.0  0.0  17.0
# 2     133.000000  0.003322  0.000000  0.008306  0.003322  0.0  0.0  16.0
# 3     134.000000  0.002561  0.000000  0.007742  0.002561  0.0  0.0  16.0
# 4     131.948232  0.006515  0.000000  0.008143  0.000000  0.0  0.0  16.0
# ...          ...       ...       ...       ...       ...  ...  ...   ...
# 2121  140.000000  0.000000  0.961268  0.007426  0.000000  0.0  0.0  79.0
# 2122  140.000000  0.000775  0.000000  0.006979  0.000000  0.0  0.0  78.0
# 2123  140.000000  0.000980  0.000000  0.006863  0.000000  0.0  0.0  79.0
# 2124  140.000000  0.000679  0.000000  0.006110  0.000000  0.0  0.0  78.0
# 2125  142.000000  0.001616 -0.000188  0.008078  0.000000  0.0  0.0  74.0
#
#       MSTV       ALTV  MLTV  Width  Tendency       NSP
# ...

# %%
df1.isnull().sum()
# Out:
# LB          0
# AC          0
# FM          0
# UC          0
# DL          0
# DS          0
# DP          0
# ASTV        0
# MSTV        0
# ALTV        0
# MLTV        0
# Width       0
# Tendency    0
# NSP         0
# dtype: int64

# %%
df.boxplot()
# Out:
# <Axes: >

# %%
for i in df.select_dtypes(include='number').columns:
    sns.boxplot(data=df,x=i)
    plt.show()

# %%
def remove_outlier(col):
    sorted(col)
    q1,q3=col.quantile([0.25,0.75])
    IQR=q3-q1
    lower_extreme=q1-(1.5*IQR)
    upper_extreme=q3+(1.5*IQR)
    return lower_extreme,upper_extreme

# %%
low,high=remove_outlier(df['MSTV'])
low,high
# Out:
# (-0.8, 3.2)

# %%
df['MSTV']=np.where(df['MSTV']>high,low,df['MSTV'])
df['MSTV']=np.where(df['MSTV']<low,high,df['MSTV'])

# %%
df.boxplot(column='MSTV')
plt.show()

# %%
Q1=df['MLTV'].quantile(0.25)
Q3=df['MLTV'].quantile(0.75)
IQR=Q3-Q1
print (Q1,Q3,IQR)
# Out:
# 4.6 10.9 6.300000000000001

# %%
lower_extreme=Q1-1.5*IQR
upper_extreme=Q3+1.5*IQR
print(lower_extreme,upper_extreme)
# Out:
# -4.850000000000001 20.35

# %%
volume_outliers=df[(df['MLTV']<lower_extreme) | (df['MLTV']>upper_extreme)]
volume_outliers
# Out:
#          LB        AC        FM        UC        DL        DS        DP  ASTV  \
# 3     134.0  0.002561  0.000000  0.007742  0.002561  0.000000  0.000000  16.0
# 10    151.0  0.000000  0.000000  0.000834  0.000834  0.000000  0.000000  64.0
# 11    150.0  0.000000  0.000000  0.001014  0.000983  0.000000  0.000000  64.0
# 33    120.0  0.007506  0.102585  0.000800  0.000834 -0.000002  0.000000  28.0
# 35    120.0  0.006061  0.109091  0.007273  0.000000  0.000000  0.000000  27.0
# ...     ...       ...       ...       ...       ...       ...       ...   ...
# 1750  134.0  0.004800  0.001600  0.001600  0.003200  0.000000  0.003200  62.0
# 1800  143.0  0.000000  0.000000  0.003717  0.000000 -0.000004  0.000000  66.0
# 1818  139.0  0.011139  0.001007  0.007049  0.000000  0.000003  0.000000  53.0
# 1882  139.0  0.001835  0.000000  0.006422  0.000000  0.000000  0.000000  58.0
# 2033  129.0  0.000000  0.001122  0.006734  0.005767  0.000004  0.002245  67.0
#
# ...

# %%
df.boxplot('MLTV')
plt.show()

# %%
volume_no_outliers=df[(df['MLTV']>=lower_extreme) & (df['MLTV']<=upper_extreme)]
volume_no_outliers
# Out:
#               LB        AC        FM        UC        DL   DS        DP  ASTV  \
# 0     120.000000  0.000000  0.000000  0.000000  0.000000  0.0  0.000000  73.0
# 1     132.000000  0.006380  0.000000  0.006380  0.003190  0.0  0.000000  17.0
# 2     133.000000  0.003322  0.000000  0.008306  0.003322  0.0  0.000000  16.0
# 4     131.948232  0.006515  0.000000  0.008143  0.000000  0.0  0.000000  16.0
# 5     134.000000  0.001116  0.000000  0.010493  0.009444  0.0  0.002099  26.0
# ...          ...       ...       ...       ...       ...  ...       ...   ...
# 2121  140.000000  0.000000  0.961268  0.007426  0.000000  0.0  0.000000  79.0
# 2122  140.000000  0.000775  0.000000  0.006979  0.000000  0.0  0.000000  78.0
# 2123  140.000000  0.000980  0.000000  0.006863  0.000000  0.0  0.000000  79.0
# 2124  140.000000  0.000679  0.000000  0.006110  0.000000  0.0  0.000000  78.0
# 2125  142.000000  0.001616 -0.000188  0.008078  0.000000  0.0  0.000000  74.0
#
# ...

# %%
volume_no_outliers.boxplot('MLTV')
plt.show()

# %%
for i in df.select_dtypes(include='number').columns:
    sns.histplot(data=df,x=i)
    plt.show()

# %%
for i in df.columns:
    sns.scatterplot(data=df,x=i)
    plt.show()

# %%
for i in df.columns:
    sns.barplot(data=df,x=i)
    plt.show()

# %%
correlation=volume_no_outliers.corr()

# %%
correlation
# Out:
#                 LB        AC        FM        UC        DL        DS  \
# LB        1.000000 -0.060509  0.022639 -0.169890 -0.123844 -0.005167
# AC       -0.060509  1.000000  0.009721  0.077719 -0.093201 -0.032006
# FM        0.022639  0.009721  1.000000 -0.052775  0.010863  0.031105
# UC       -0.169890  0.077719 -0.052775  1.000000  0.187489 -0.009420
# DL       -0.123844 -0.093201  0.010863  0.187489  1.000000  0.062600
# DS       -0.005167 -0.032006  0.031105 -0.009420  0.062600  1.000000
# DP       -0.044243 -0.086236  0.117660  0.071763  0.144902  0.000331
# ASTV      0.249225 -0.241649 -0.030730 -0.179328 -0.069089  0.011382
# MSTV     -0.264824  0.195993  0.041253  0.245954  0.308176  0.029941
# ALTV      0.218620 -0.279416 -0.012069 -0.230863 -0.191413 -0.002902
# MLTV     -0.065943 -0.149497 -0.002835 -0.080356 -0.252914 -0.013790
# Width    -0.135196  0.244149  0.099567  0.111742  0.426783  0.041195
# Tendency  0.224741  0.038811 -0.015057 -0.069797 -0.012507 -0.019604
# ...

# %%
plt.figure(figsize=(12,6))
sns.heatmap(correlation,annot=True,cmap='Blues')
plt.show()

# %%
def correlation(dataset,thershold):
    corr= dataset.corr()
    col_corr=set()
    for i in range(len(corr.columns)):
        for j in range(i):
            if abs(corr.iloc[i,j])>thershold:
                col_name= corr.columns[i]
                col_corr.add(col_name)
    return col_corr

# %%
correlation(volume_no_outliers,0.3)
# Out:
# {'ALTV', 'MSTV', 'NSP', 'Width'}

# %% [markdown]
# ## 	Conclusion:

# %% [markdown]
# ## 1.Summarize the key insights and patterns discovered through your exploratory analysis.

# %% [markdown]
# 1. Data Distribution:
#
# Skewness and Kurtosis: Identifying whether data distributions are skewed or have heavy tails can inform necessary transformations (e.g., log transformation) for better model performance.
#
# Outliers: Detection of outliers can indicate data quality issues or unique observations that require special handling.

# %% [markdown]
# 2. Correlations:
#
# Feature Relationships: Heatmaps or scatter plots reveal correlations between features, helping to identify which variables are strongly associated and potentially multicollinear.
#
# Target Variable Relations: Understanding how different features relate to the target variable can guide feature selection and engineering efforts.

# %% [markdown]
# 3. Missing Values:
#
# Patterns of Missingness: Analyzing missing data patterns can suggest whether data is missing at random or systematically, influencing imputation strategies.
#
# Impact on Analysis: Assessing how missing values impact distributions or correlations can inform decisions on whether to drop or fill missing data.

# %% [markdown]
# 4. Visual Patterns:
#
# Graphs and Plots: Visualizations can reveal trends and relationships that numerical summaries may not capture, emphasizing the importance of graphical exploration.

# %% [markdown]
# ## 2.Discuss how these findings could impact decision-making or further analyses.

# %% [markdown]
# 1. Data Quality Improvement:
#
# Impact: Identifying missing values, outliers, and inconsistencies helps improve the overall quality of the dataset.
#
# Decision-Making: Ensuring high-quality data leads to more reliable analyses and models, reducing the risk of incorrect conclusions that could impact business strategies.

# %% [markdown]
# 2. Feature Engineering:
#
# Impact: Insights from feature relationships and distributions can inform the creation of new features or transformations.
#
# Decision-Making: Better features enhance model performance, enabling more accurate predictions that support strategic decisions, such as targeting specific customer segments.

# %% [markdown]
# 3. Communication of Insights:
#
# Impact: Visualizations and summary statistics from EDA make complex data more accessible and understandable to stakeholders.
#
# Decision-Making: Clear communication of findings fosters a data-driven culture, encouraging stakeholders to base decisions on empirical evidence rather than intuition
